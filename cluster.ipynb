# %%
import pandas as pd
from minisom import MiniSom
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
df=pd.read_csv('data_monthly.csv',index_col=0)

df_1=df[df.columns[~df.columns.isin(['latitude','longitude'])]]

data_1=df_1.T[:20*12].T
data_2=df_1.T[20*12:40*12].T
data_3=df_1.T[40*12:60*12].T
data_4=df_1.T[60*12:80*12].T
data_5=df_1.T[80*12:100*12].T
data_6=df_1.T[100*12:121*12].T

# %%
data_11=data_1.values
data_21=data_2.values
data_31=data_3.values
data_41=data_4.values
data_51=data_5.values
data_61=data_6.values

# %%
som_shape = (1, 7)
som = MiniSom(som_shape[0], som_shape[1], data_11.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_11, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_11))
    som.update(data_11[rand_i], som.winner(data_11[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_11]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_1['cluster']=cluster_index
########################################################3


som_shape = (1, 7)
som = MiniSom(som_shape[0], som_shape[1], data_21.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_21, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_21))
    som.update(data_21[rand_i], som.winner(data_21[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_21]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_2['cluster']=cluster_index
########################################################3


som_shape = (1, 7)
som = MiniSom(som_shape[0], som_shape[1], data_31.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_31, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_31))
    som.update(data_31[rand_i], som.winner(data_31[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_31]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_3['cluster']=cluster_index
########################################################3


som_shape = (1, 7)
som = MiniSom(som_shape[0], som_shape[1], data_41.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_41, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_41))
    som.update(data_41[rand_i], som.winner(data_41[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_41]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_4['cluster']=cluster_index
########################################################3


som_shape = (1, 7)
som = MiniSom(som_shape[0], som_shape[1], data_51.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_51, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_51))
    som.update(data_51[rand_i], som.winner(data_51[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_51]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_5['cluster']=cluster_index
########################################################3


som_shape = (1, 7)
som = MiniSom(som_shape[0], som_shape[1], data_61.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_61, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_61))
    som.update(data_61[rand_i], som.winner(data_61[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_61]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_6['cluster']=cluster_index
########################################################3




lat=df['latitude']
lon=df['longitude']

data_1['latitude']=lat

data_1['longitude']=lon

data_2['latitude']=lat
data_2['longitude']=lon

data_3['latitude']=lat
data_3['longitude']=lon

data_4['latitude']=lat
data_4['longitude']=lon

data_5['latitude']=lat
data_5['longitude']=lon

data_6['latitude']=lat
data_6['longitude']=lon
title_1=data_1.columns[0][:4]+'-'+data_1.columns[-4][:4]+" Rainfall"
title_2=data_2.columns[0][:4]+'-'+data_2.columns[-4][:4]+" Rainfall"
title_3=data_3.columns[0][:4]+'-'+data_3.columns[-4][:4]+" Rainfall"
title_4=data_4.columns[0][:4]+'-'+data_4.columns[-4][:4]+" Rainfall"
title_5=data_5.columns[0][:4]+'-'+data_5.columns[-4][:4]+" Rainfall"
title_6=data_6.columns[0][:4]+'-'+data_6.columns[-4][:4]+" Rainfall"


# Plotting the clusters 
classes=["1","2","3","4","5","6","7"]
fig = plt.figure()    
fig, axes = plt.subplots(nrows = 2, ncols = 3,figsize=(20,12))
a=axes[0][0].scatter(data_1['longitude'],data_1['latitude'],c=data_1['cluster'], alpha=.7)
axes[0][0].scatter(78.491,17,387,c='r',marker="*")
axes[0][0].set_xlabel('Longitude')
axes[0][0].set_ylabel('Latitude')
axes[0][0].set_title(title_1)
axes[0][0].legend(handles=a.legend_elements()[0],labels=classes,loc='best')

b=axes[0][1].scatter(data_2['longitude'],data_2['latitude'],c=data_2['cluster'], alpha=.7)
axes[0][1].scatter(78.491,17,387,c='r',marker="*")
axes[0][1].set_xlabel('Longitude')
axes[0][1].set_ylabel('Latitude')
axes[0][1].set_title(title_2)
axes[0][1].legend(handles=b.legend_elements()[0],labels=classes,loc='best')

c=axes[0][2].scatter(data_3['longitude'],data_3['latitude'],c=data_3['cluster'], alpha=.7)
axes[0][2].scatter(78.491,17,387,c='r',marker="*")
axes[0][2].set_xlabel('Longitude')
axes[0][2].set_ylabel('Latitude')
axes[0][2].set_title(title_3)
axes[0][2].legend(handles=c.legend_elements()[0],labels=classes,loc='best')

d=axes[1][0].scatter(data_4['longitude'],data_4['latitude'],c=data_4['cluster'], alpha=.7)
axes[1][0].scatter(78.491,17,387,c='r',marker="*")
axes[1][0].set_xlabel('Longitude')
axes[1][0].set_ylabel('Latitude')
axes[1][0].set_title(title_4)
axes[1][0].legend(handles=d.legend_elements()[0],labels=classes,loc='best')

e=axes[1][1].scatter(data_5['longitude'],data_5['latitude'],c=data_5['cluster'], alpha=.7)
axes[1][1].scatter(78.491,17,387,c='r',marker="*")
axes[1][1].set_xlabel('Longitude')
axes[1][1].set_ylabel('Latitude')
axes[1][1].set_title(title_5)
axes[1][1].legend(handles=e.legend_elements()[0],labels=classes,loc='best')

f=axes[1][2].scatter(data_6['longitude'],data_6['latitude'],c=data_6['cluster'], alpha=.7)
axes[1][2].scatter(78.491,17,387,c='r',marker="*")
axes[1][2].set_xlabel('Longitude')
axes[1][2].set_ylabel('Latitude')
axes[1][2].set_title(title_6)
axes[1][2].legend(handles=f.legend_elements()[0],labels=classes,loc='best')


fig.suptitle("Homogeneous Regions of India",fontsize=18)
plt.savefig("rainfall_6_decades_1.png")
# Out:
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1301.4921433157035
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1459.8164005690132
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1547.9434025007158
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1512.8423568141664
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1520.6824275696883
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1548.8583269458497

# %%
title_1=data_1.columns[0][:4]+'-'+data_1.columns[-4][:4]+" Rainfall"
title_2=data_2.columns[0][:4]+'-'+data_2.columns[-4][:4]+" Rainfall"
title_3=data_3.columns[0][:4]+'-'+data_3.columns[-4][:4]+" Rainfall"
title_4=data_4.columns[0][:4]+'-'+data_4.columns[-4][:4]+" Rainfall"
title_5=data_5.columns[0][:4]+'-'+data_5.columns[-4][:4]+" Rainfall"
title_6=data_6.columns[0][:4]+'-'+data_6.columns[-4][:4]+" Rainfall"

# %%
print(title_1,title_2)
# Out:
# 1901-1920 Rainfall 1921-1940 Rainfall

# %% [markdown]
# # Cluster Region of India's Rainfall (4,5,6,7 cluster regions)

# %%
df=pd.read_csv('data_monthly.csv',index_col=0)
lat=df['latitude']
lon=df['longitude']
df_1=df[df.columns[~df.columns.isin(['latitude','longitude'])]]

# %%
data=df_1.values
som_shape = (1, 4)
som = MiniSom(som_shape[0], som_shape[1], data.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data))
    som.update(data[rand_i], som.winner(data[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
df_1['cluster_1']=cluster_index
########################################################3
som_shape = (1, 5)
som = MiniSom(som_shape[0], som_shape[1], data.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data))
    som.update(data[rand_i], som.winner(data[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
df_1['cluster_2']=cluster_index
########################################################3
som_shape = (1, 6)
som = MiniSom(som_shape[0], som_shape[1], data.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data))
    som.update(data[rand_i], som.winner(data[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
df_1['cluster_3']=cluster_index
########################################################
som_shape = (1, 7)
som = MiniSom(som_shape[0], som_shape[1], data.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data))
    som.update(data[rand_i], som.winner(data[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
df_1['cluster_4']=cluster_index
# Out:
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 3914.095154491688
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 3890.337896126514
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 3800.4038342722797
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 3745.737490209416

# %%
df_1['latitude']=lat

df_1['longitude']=lon

# %%
# Plotting the clusters 
classes=["1","2","3","4","5","6","7"]
fig = plt.figure()    
fig, axes = plt.subplots(nrows = 2, ncols = 2,figsize=(15,12))
a=axes[0][0].scatter(df_1['longitude'],df_1['latitude'],c=df_1['cluster_1'], alpha=.7)
axes[0][0].scatter(78.491,17,387,c='r',marker="*")
axes[0][0].set_xlabel('Longitude')
axes[0][0].set_ylabel('Latitude')
axes[0][0].set_title("Rainfall Based Clusters: 4")
axes[0][0].legend(handles=a.legend_elements()[0],labels=classes,loc='best')

b=axes[0][1].scatter(df_1['longitude'],df_1['latitude'],c=df_1['cluster_2'], alpha=.7)
axes[0][1].scatter(78.491,17,387,c='r',marker="*")
axes[0][1].set_xlabel('Longitude')
axes[0][1].set_ylabel('Latitude')
axes[0][1].set_title("Rainfall Based Clusters: 5")
axes[0][1].legend(handles=b.legend_elements()[0],labels=classes,loc='best')

c=axes[1][0].scatter(df_1['longitude'],df_1['latitude'],c=df_1['cluster_3'], alpha=.7)
axes[1][0].scatter(78.491,17,387,c='r',marker="*")
axes[1][0].set_xlabel('Longitude')
axes[1][0].set_ylabel('Latitude')
axes[1][0].set_title("Rainfall Based Clusters: 5")
axes[1][0].legend(handles=c.legend_elements()[0],labels=classes,loc='best')

d=axes[1][1].scatter(df_1['longitude'],df_1['latitude'],c=df_1['cluster_4'], alpha=.7)
axes[1][1].scatter(78.491,17,387,c='r',marker="*")
axes[1][1].set_xlabel('Longitude')
axes[1][1].set_ylabel('Latitude')
axes[1][1].set_title("Rainfall Based Clusters: 7")
axes[1][1].legend(handles=d.legend_elements()[0],labels=classes,loc='best')
fig.suptitle("Homogeneous Regions of India Based on Rainfall Patterns 1901-2021",fontsize=15)
plt.savefig("rainfall_4 clusters.png")

# %%
plt.figure(figsize=(8,8))
d=plt.scatter(df_1['longitude'],df_1['latitude'],c=df_1['cluster_4'], alpha=.7)
plt.scatter(78.491,17,387,c='r',marker="*")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title("Homogeneous Regions of India: Rainfall Patterns 1901-2021",fontsize=15)
plt.legend(handles=d.legend_elements()[0],labels=classes,loc='best')
plt.savefig("rainfall_7_clusters.png")

# %%
df_2=df_1
data=df_2.values

########################################################
som_shape = (1, 8)
som = MiniSom(som_shape[0], som_shape[1], data.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian',random_seed=10)
som.train_batch(data, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data))
    som.update(data[rand_i], som.winner(data[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
df_2['cluster_6']=cluster_index

plt.figure(figsize=(8,8))
class_1=['C1','C2','C3','C4','C5','C6','C7','C8','C9',"C10"]
d=plt.scatter(df_1['longitude'],df_1['latitude'],c=df_1['cluster_6'], alpha=.7,cmap="Blues_r")
plt.scatter(78.491,17,387,c='r',marker="*")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title("Homogeneous Regions of India: Rainfall Patterns 1901-2021",fontsize=15)
plt.legend(handles=d.legend_elements()[0],labels=class_1,loc='best')
plt.savefig("rainfall_8_clusters.png")
# Out:
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 3748.3916439858044

# %%
df_2=df_1
data=df_2.values

########################################################
som_shape = (1, 10)
som = MiniSom(som_shape[0], som_shape[1], data.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian')
som.train_batch(data, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data))
    som.update(data[rand_i], som.winner(data[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
df_2['cluster_6']=cluster_index

plt.figure(figsize=(8,8))
class_1=['C1','C2','C3','C4','C5','C6','C7','C8','C9',"C10"]
d=plt.scatter(df_2['longitude'],df_2['latitude'],c=df_2['cluster_6'], alpha=.7)
plt.scatter(78.491,17,387,c='r',marker="*")
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title("Homogeneous Regions of India: Rainfall Patterns 1901-2021",fontsize=15)
plt.legend(handles=d.legend_elements()[0],labels=class_1,loc='best')
plt.savefig("rainfall_10_clusters_final_1.png")
# Out:
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 3717.612041433892

# %%
grid=df_2[df_2.columns[df_2.columns.isin(['cluster_6',"latitude","longitude"])]]

# %%
grid.groupby('cluster_6')['latitude'].count()
# Out:
# cluster_6
# 0     878
# 1     261
# 2    1099
# 3     152
# 4     532
# 5      99
# 6     484
# 7     127
# 8     546
# 9     786
# Name: latitude, dtype: int64

# %%
df.set_index(['latitude','longitude'],inplace=True)

# %%
annual=df.T

# %%
annual.index=pd.date_range("1901-01-01",periods=annual.shape[0],freq='MS')

# %%
annual=annual.resample('A').sum()

# %%
annual
# Out:
# latitude         37.25                                       37.00  \
# longitude        74.75        75.00        75.25 75.50       73.75
# 1901-12-31  121.499999   121.499999   121.499999   0.0  121.499999
# 1902-12-31  146.000000   146.000000   146.000000   0.0  146.000000
# 1903-12-31  125.599999   125.599999   125.599999   0.0  125.599999
# 1904-12-31  108.400000   108.400000   108.400000   0.0  108.400000
# 1905-12-31  194.499997   194.499997   194.499997   0.0  194.499997
# ...                ...          ...          ...   ...         ...
# 2017-12-31  717.399998   803.600001   864.400001   0.0  430.600003
# 2018-12-31  484.100000   609.999997   713.699997   0.0  117.600000
# 2019-12-31  987.370937  1011.535021  1009.711823   0.0  758.291593
# 2020-12-31  854.871917   814.926113   763.607911   0.0  852.516773
# 2021-12-31  534.208854   571.010541   593.390869   0.0  366.952897
#
# latitude                                                                   \
# ...

# %%
df_new=df_1[df_1.columns[~df_1.columns.isin(['cluster_1',"cluster_2","cluster_3","cluster_5",'cluster_4'])]]

# %%
df_new.rename(columns = {'cluster_6':'Clusters'}, inplace = True)

# %% [markdown]
# # mean rainfall

# %%
mean_rainfall=df_new.groupby("Clusters").mean()
mean_rainfall=mean_rainfall[mean_rainfall.columns[~mean_rainfall.columns.isin(['latitude','longitude'])]]

# %%
values = mean_rainfall.T.values
values.shape
# Out:
# (1452, 10)

# %%
values
# Out:
# array([[ 21.80284739,  80.65095786,  55.73375798, ...,  26.68818899,
#          14.51117215,  11.0557252 ],
#        [ 21.97915717,  78.27126422,  37.44986351, ...,  59.88110261,
#          41.85531137,   4.89872773],
#        [  9.61127564,  51.48160905,  13.94540494, ...,  11.44409451,
#           8.88846156,   2.50063614],
#        ...,
#        [ 57.99759728,  68.77832097,  91.27031044, ..., 120.01902318,
#         177.53083455,  13.95402348],
#        [ 21.72618924,   2.37861233,   8.20894324, ..., 146.5845441 ,
#         308.5143051 ,   1.29210935],
#        [  8.66001343,  14.55821846,  13.24484243, ...,  39.83293351,
#          38.56299623,   2.03423785]])

# %%
# specify columns to plot
groups = np.arange(10)
i = 1
# plot each column
fig, axs = plt.subplots(len(groups), 1, figsize=(20, 15))
c=['red','blue','green','cyan','orange','magenta','palegreen','purple','black','yellow']
for i, group in enumerate(groups):
    axs[i].plot(values[:, group], color=c[i])
    axs[i].set_title(f"C{i}", fontweight='bold')
    axs[i].set_xlabel('No. of days')
    axs[i].set_ylabel("Mean_PPT(mm)")
    i+=1
fig.suptitle('Year 1901-2021',fontsize=16,fontweight='bold')

plt.savefig('mean_rainfall_cluster_final.png')
plt.show()

# %%
mean_rainfall.T.describe().to_csv("Mean_rainfall.csv")

# %%
mean_rainfall.T.describe()
# Out:
# Clusters            0            1            2            3            4  \
# count     1452.000000  1452.000000  1452.000000  1452.000000  1452.000000
# mean        63.721342    70.867360    88.904354   277.016513   122.597538
# std         81.600159    52.474750   115.295479   261.309239   155.888590
# min          0.002164     0.000000     0.086442     0.164474     0.107707
# 25%          5.737329    32.495594     9.090218    44.248355    12.841541
# 50%         16.040661    62.050575    24.729026   194.706250    34.721119
# 75%        113.079100    95.547031   144.892630   465.629440   206.330498
# max        377.155239   520.383525   440.108917  1416.130262   625.212218
#
# Clusters            5            6            7            8            9
# count     1452.000000  1452.000000  1452.000000  1452.000000  1452.000000
# mean       264.088749   158.849342   103.212276    64.974361    22.024103
# std        375.817390   138.878952   100.845738    56.144416    29.798693
# ...

# %%
df.T
# Out:
# latitude                  37.25                                   37.00  \
# longitude                 74.75      75.00      75.25 75.50       73.75
# 1901-01-01 00:00:00    6.400000   6.400000   6.400000   0.0    6.400000
# 1901-02-01 00:00:00    2.000000   2.000000   2.000000   0.0    2.000000
# 1901-03-01 00:00:00    3.800000   3.800000   3.800000   0.0    3.800000
# 1901-04-01 00:00:00    7.100000   7.100000   7.100000   0.0    7.100000
# 1901-05-01 00:00:00   22.100000  22.100000  22.100000   0.0   22.100000
# ...                         ...        ...        ...   ...         ...
# 2021-08-01 00:00:00   13.861914  16.329034  17.953028   0.0    3.678716
# 2021-09-01 00:00:00  100.260022  80.854628  63.793888   0.0  162.460879
# 2021-10-01 00:00:00   65.235641  68.088913  70.642146   0.0   61.024402
# 2021-11-01 00:00:00    2.422658   2.851044   3.149002   0.0    0.685788
# 2021-12-01 00:00:00    7.549552   9.096201  10.259153   0.0    2.051089
#
# ...

# %%
df_2.columns
# Out:
# Index(['1901-01-01 00:00:00', '1901-02-01 00:00:00', '1901-03-01 00:00:00',
#        '1901-04-01 00:00:00', '1901-05-01 00:00:00', '1901-06-01 00:00:00',
#        '1901-07-01 00:00:00', '1901-08-01 00:00:00', '1901-09-01 00:00:00',
#        '1901-10-01 00:00:00',
#        ...
#        '2021-10-01 00:00:00', '2021-11-01 00:00:00', '2021-12-01 00:00:00',
#        'cluster_1', 'cluster_2', 'cluster_3', 'cluster_4', 'latitude',
#        'longitude', 'cluster_6'],
#       dtype='object', length=1459)

# %%
data_plot=df_1[df_1.columns[df_1.columns.isin(['latitude',"longitude","2021-11-01 00:00:00"])]]

# %% [markdown]
# # Clusters of size 10

# %%
print(df.columns)
# Out:
# Index(['1901-01-01 00:00:00', '1901-02-01 00:00:00', '1901-03-01 00:00:00',
#        '1901-04-01 00:00:00', '1901-05-01 00:00:00', '1901-06-01 00:00:00',
#        '1901-07-01 00:00:00', '1901-08-01 00:00:00', '1901-09-01 00:00:00',
#        '1901-10-01 00:00:00',
#        ...
#        '2021-03-01 00:00:00', '2021-04-01 00:00:00', '2021-05-01 00:00:00',
#        '2021-06-01 00:00:00', '2021-07-01 00:00:00', '2021-08-01 00:00:00',
#        '2021-09-01 00:00:00', '2021-10-01 00:00:00', '2021-11-01 00:00:00',
#        '2021-12-01 00:00:00'],
#       dtype='object', length=1452)

# %%
som_shape = (1,10)
som = MiniSom(som_shape[0], som_shape[1], data_11.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_11, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_11))
    som.update(data_11[rand_i], som.winner(data_11[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_11]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_1['cluster']=cluster_index
########################################################3


som_shape = (1,10)
som = MiniSom(som_shape[0], som_shape[1], data_21.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_21, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_21))
    som.update(data_21[rand_i], som.winner(data_21[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_21]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_2['cluster']=cluster_index
########################################################3


som_shape = (1,10)
som = MiniSom(som_shape[0], som_shape[1], data_31.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_31, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_31))
    som.update(data_31[rand_i], som.winner(data_31[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_31]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_3['cluster']=cluster_index
########################################################3


som_shape = (1,10)
som = MiniSom(som_shape[0], som_shape[1], data_41.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_41, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_41))
    som.update(data_41[rand_i], som.winner(data_41[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_41]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_4['cluster']=cluster_index
########################################################3


som_shape = (1,10)
som = MiniSom(som_shape[0], som_shape[1], data_51.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_51, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_51))
    som.update(data_51[rand_i], som.winner(data_51[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_51]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_5['cluster']=cluster_index
########################################################3


som_shape = (1,10)
som = MiniSom(som_shape[0], som_shape[1], data_61.shape[1], sigma=.5, learning_rate=.5,
              neighborhood_function='gaussian', random_seed=10)
som.train_batch(data_61, 700, verbose=True)
max_iter = 350
#q_error = []
#t_error = []
for i in range(max_iter):
    rand_i = np.random.randint(len(data_61))
    som.update(data_61[rand_i], som.winner(data_61[rand_i]), i, max_iter)
# each neuron represents a cluster
winner_coordinates = np.array([som.winner(x) for x in data_61]).T
cluster_index = np.ravel_multi_index(winner_coordinates, som_shape)
data_6['cluster']=cluster_index
########################################################3


df=pd.read_csv('data_monthly.csv',index_col=0)


lat=df['latitude']
lon=df['longitude']

data_1['latitude']=lat

data_1['longitude']=lon

data_2['latitude']=lat
data_2['longitude']=lon

data_3['latitude']=lat
data_3['longitude']=lon

data_4['latitude']=lat
data_4['longitude']=lon

data_5['latitude']=lat
data_5['longitude']=lon

data_6['latitude']=lat
data_6['longitude']=lon
title_1=data_1.columns[0][:4]+'-'+data_1.columns[-4][:4]+" Rainfall"
title_2=data_2.columns[0][:4]+'-'+data_2.columns[-4][:4]+" Rainfall"
title_3=data_3.columns[0][:4]+'-'+data_3.columns[-4][:4]+" Rainfall"
title_4=data_4.columns[0][:4]+'-'+data_4.columns[-4][:4]+" Rainfall"
title_5=data_5.columns[0][:4]+'-'+data_5.columns[-4][:4]+" Rainfall"
title_6=data_6.columns[0][:4]+'-'+data_6.columns[-4][:4]+" Rainfall"


# Plotting the clusters 
classes=['C1','C2','C3','C4','C5','C6','C7','C8','C9',"C10"]
fig = plt.figure()    
fig, axes = plt.subplots(nrows = 2, ncols = 3,figsize=(20,12))
a=axes[0][0].scatter(data_1['longitude'],data_1['latitude'],c=data_1['cluster'], alpha=.7,cmap="winter")
axes[0][0].scatter(78.491,17,387,c='r',marker="*")
axes[0][0].set_xlabel('Longitude')
axes[0][0].set_ylabel('Latitude')
axes[0][0].set_title(title_1)
axes[0][0].legend(handles=a.legend_elements()[0],labels=classes,loc='best')

b=axes[0][1].scatter(data_2['longitude'],data_2['latitude'],c=data_2['cluster'], alpha=.7,cmap="winter")
axes[0][1].scatter(78.491,17,387,c='r',marker="*")
axes[0][1].set_xlabel('Longitude')
axes[0][1].set_ylabel('Latitude')
axes[0][1].set_title(title_2)
axes[0][1].legend(handles=b.legend_elements()[0],labels=classes,loc='best')

c=axes[0][2].scatter(data_3['longitude'],data_3['latitude'],c=data_3['cluster'], alpha=.7,cmap="winter")
axes[0][2].scatter(78.491,17,387,c='r',marker="*")
axes[0][2].set_xlabel('Longitude')
axes[0][2].set_ylabel('Latitude')
axes[0][2].set_title(title_3)
axes[0][2].legend(handles=c.legend_elements()[0],labels=classes,loc='best')

d=axes[1][0].scatter(data_4['longitude'],data_4['latitude'],c=data_4['cluster'], alpha=.7,cmap="winter")
axes[1][0].scatter(78.491,17,387,c='r',marker="*")
axes[1][0].set_xlabel('Longitude')
axes[1][0].set_ylabel('Latitude')
axes[1][0].set_title(title_4)
axes[1][0].legend(handles=d.legend_elements()[0],labels=classes,loc='best')

e=axes[1][1].scatter(data_5['longitude'],data_5['latitude'],c=data_5['cluster'], alpha=.7,cmap="winter")
axes[1][1].scatter(78.491,17,387,c='r',marker="*")
axes[1][1].set_xlabel('Longitude')
axes[1][1].set_ylabel('Latitude')
axes[1][1].set_title(title_5)
axes[1][1].legend(handles=e.legend_elements()[0],labels=classes,loc='best')

f=axes[1][2].scatter(data_6['longitude'],data_6['latitude'],c=data_6['cluster'], alpha=.7,cmap="winter")
axes[1][2].scatter(78.491,17,387,c='r',marker="*")
axes[1][2].set_xlabel('Longitude')
axes[1][2].set_ylabel('Latitude')
axes[1][2].set_title(title_6)
axes[1][2].legend(handles=f.legend_elements()[0],labels=classes,loc='best')


fig.suptitle("Homogeneous Regions of India",fontsize=18)
plt.savefig("rainfall_decades_10.png")
# Out:
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1295.1339988825368
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1459.6585987140768
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1519.5128288634014
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1512.8411346753362
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1520.6807335710046
#  [ 700 / 700 ] 100% - 0:00:00 left
#  quantization error: 1530.1523620285975

# %%
Colormap Blue is not recognized. Possible values are:
    Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r,
    CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, 
    OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r
    , Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r,
    PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, inferno, inferno_r, jet, jet_r, magma, magma_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight,
    twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, winter, winter_r
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_6368\3809590058.py", line 1
#     Colormap Blue is not recognized. Possible values are:
#              ^
# SyntaxError: invalid syntax
